# %% [markdown]
# # Lab 01 - Data Loading: Impact of AI on Students
#
#         Source dataset: `Datasets/Impact of AI on Students/ai_student_impact_dataset.csv`
#
#         This notebook adapts the class lab pattern to the student-impact dataset. The source file is never modified.
#
#         ## Lab concepts used
#
#         - Locate and load a CSV with pandas.
# - Inspect rows, columns, shape, and data types.
# - Preserve the raw input.
#
#         Interpretation is predictive and associative only. The Kaggle source does not document how the records were collected or whether they represent observed students.

# %%
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid")
RANDOM_STATE = 42

def find_dataset():
    relative = Path("Datasets/Impact of AI on Students/ai_student_impact_dataset.csv")
    for start in [Path.cwd(), *Path.cwd().parents]:
        candidate = start / relative
        if candidate.exists():
            return candidate
    raise FileNotFoundError(f"Could not locate {relative} from {Path.cwd()}")

DATA_PATH = find_dataset()
df = pd.read_csv(DATA_PATH)
print(f"Loaded {df.shape[0]:,} rows and {df.shape[1]} columns from {DATA_PATH}")

# %% [markdown]
# ## First and last records

# %%
display(df.head())
display(df.tail())

# %% [markdown]
# ## Structure

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
print("\nData types:")
display(df.dtypes.rename("dtype").to_frame())

# %% [markdown]
# ## Basic integrity checks

# %%
integrity = pd.Series({
    "rows": len(df),
    "columns": df.shape[1],
    "missing_cells": int(df.isna().sum().sum()),
    "duplicate_rows": int(df.duplicated().sum()),
    "unique_student_ids": int(df["Student_ID"].nunique()),
})
display(integrity.to_frame("value"))

# %% [markdown]
# ## What was learned from Lab 1
#
# The file contains 50,000 rows and 16 columns. It loads cleanly, has no missing cells or duplicated rows, and contains a unique identifier that must be excluded from modelling.
