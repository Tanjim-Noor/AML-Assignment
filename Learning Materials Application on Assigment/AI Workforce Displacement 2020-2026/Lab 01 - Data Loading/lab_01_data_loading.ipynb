# %% [markdown]
# # Lab 01 - Data Loading: AI Workforce Displacement 2020-2026
#
# This notebook applies **Lab 1 - Installing IDE/Data Loading** to the assignment dataset. The aim is to load the local CSV with pandas and inspect the loaded dataframe before any preprocessing or modelling.

# %% [markdown]
# ## Lab 1 concepts used
#
# - Confirm the Python data-analysis stack.
# - Import pandas.
# - Load a local CSV file with `pd.read_csv`.
# - Configure dataframe display settings.
# - View the loaded dataframe, first rows, last rows, shape, columns, and dtypes.
#
# The Lab 1 Excel and URL examples are not repeated here because this assignment dataset is already available as a local CSV file.

# %%
import pandas as pd
from pathlib import Path

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'AML Assignment' and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent
PROJECT_ROOT
# Out:
# WindowsPath('D:/APU Study/1st Semester/Applied Machine Learning/AML Assignment')

# %%
DATASET_FILENAME = 'ai_workforce_displacement_global_2020_2026.csv'
matches = sorted((PROJECT_ROOT / 'Datasets').glob(f'*/{DATASET_FILENAME}'))
if not matches:
    raise FileNotFoundError(f'Could not find {DATASET_FILENAME} under {PROJECT_ROOT / "Datasets"}')
DATASET_PATH = matches[0]
print(DATASET_PATH)
print('File exists:', DATASET_PATH.exists())
# Out:
# D:\APU Study\1st Semester\Applied Machine Learning\AML Assignment\Datasets\AI Workforce Displacement 2020–2026\ai_workforce_displacement_global_2020_2026.csv
# File exists: True

# %%
data = pd.read_csv(DATASET_PATH)
data
# Out:
#        record_id        country iso3_code         region         income_group  \
# 0              1  United States       USA  North America          High Income
# 1              2  United States       USA  North America          High Income
# 2              3  United States       USA  North America          High Income
# 3              4  United States       USA  North America          High Income
# 4              5  United States       USA  North America          High Income
# ...          ...            ...       ...            ...                  ...
# 20795      20796         Zambia       ZMB         Africa  Lower Middle Income
# 20796      20797         Zambia       ZMB         Africa  Lower Middle Income
# 20797      20798         Zambia       ZMB         Africa  Lower Middle Income
# 20798      20799         Zambia       ZMB         Africa  Lower Middle Income
# 20799      20800         Zambia       ZMB         Africa  Lower Middle Income
#
# ...

# %%
data.head()
# Out:
#    record_id        country iso3_code         region income_group  year  \
# 0          1  United States       USA  North America  High Income  2020
# 1          2  United States       USA  North America  High Income  2020
# 2          3  United States       USA  North America  High Income  2020
# 3          4  United States       USA  North America  High Income  2020
# 4          5  United States       USA  North America  High Income  2020
#
#    quarter quarter_label             industry_sector  \
# 0        1       2020-Q1       Technology & Software
# 1        1       2020-Q1           Finance & Banking
# 2        1       2020-Q1  Healthcare & Life Sciences
# 3        1       2020-Q1    Manufacturing & Industry
# 4        1       2020-Q1         Retail & E-Commerce
#
#    sector_automation_risk_score  gdp_per_capita_usd  ai_adoption_index  \
# 0                         0.382               63514              0.830
# ...

# %%
data.tail()
# Out:
#        record_id country iso3_code  region         income_group  year  \
# 20795      20796  Zambia       ZMB  Africa  Lower Middle Income  2026
# 20796      20797  Zambia       ZMB  Africa  Lower Middle Income  2026
# 20797      20798  Zambia       ZMB  Africa  Lower Middle Income  2026
# 20798      20799  Zambia       ZMB  Africa  Lower Middle Income  2026
# 20799      20800  Zambia       ZMB  Africa  Lower Middle Income  2026
#
#        quarter quarter_label             industry_sector  \
# 20795        2       2026-Q2        Education & Research
# 20796        2       2026-Q2  Transportation & Logistics
# 20797        2       2026-Q2      Media & Communications
# 20798        2       2026-Q2   Administrative & Clerical
# 20799        2       2026-Q2          Energy & Utilities
#
#        sector_automation_risk_score  gdp_per_capita_usd  ai_adoption_index  \
# 20795                         0.308                1467              0.703
# ...

# %%
data.shape
# Out:
# (20800, 23)

# %%
list(data.columns)
# Out:
# ['record_id',
#  'country',
#  'iso3_code',
#  'region',
#  'income_group',
#  'year',
#  'quarter',
#  'quarter_label',
#  'industry_sector',
#  'sector_automation_risk_score',
#  'gdp_per_capita_usd',
#  'ai_adoption_index',
#  'pct_sector_workforce_displaced',
#  'pct_sector_workforce_new_roles_created',
#  'net_workforce_change_pct',
#  'ai_cited_layoff_announcements',
#  'ai_skill_wage_premium_pct',
#  'pct_workforce_female',
#  'pct_displaced_roles_female',
#  'reskilling_programs_count',
#  'govt_ai_policy_score_1_to_10',
#  'ai_tool_adoption_pct',
#  'data_source_notes']

# %%
data.dtypes
# Out:
# record_id                         int64
# country                             str
# iso3_code                           str
# region                              str
# income_group                        str
#                                  ...
# pct_displaced_roles_female      float64
# reskilling_programs_count         int64
# govt_ai_policy_score_1_to_10    float64
# ai_tool_adoption_pct            float64
# data_source_notes                   str
# Length: 23, dtype: object

# %% [markdown]
# ## What was learned from Lab 1
#
# The dataset was loaded from `Datasets/AI Workforce Displacement 2020?2026/ai_workforce_displacement_global_2020_2026.csv` using pandas. At this stage we only confirm that the file can be read and that the dataframe structure is visible. Data cleaning, preprocessing, and modelling are intentionally left for later labs.
