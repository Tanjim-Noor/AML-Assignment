# %% [markdown]
# # Lab 01 - Data Loading: LLM Hallucination
#
# This notebook applies **Lab 1 - Installing IDE/Data Loading** to the assignment dataset. The aim is to load the local CSV with pandas and inspect the loaded dataframe before any preprocessing or modelling.

# %% [markdown]
# ## Lab 1 concepts used
#
# - Confirm the Python data-analysis stack.
# - Import pandas.
# - Load a local CSV file with `pd.read_csv`.
# - Configure dataframe display settings.
# - View the loaded dataframe, first rows, last rows, shape, columns, and dtypes.
#
# The Lab 1 Excel and URL examples are not repeated here because this assignment dataset is already available as a local CSV file.

# %%
import pandas as pd
from pathlib import Path

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
while PROJECT_ROOT.name != 'AML Assignment' and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent
PROJECT_ROOT
# Out:
# WindowsPath('D:/APU Study/1st Semester/Applied Machine Learning/AML Assignment')

# %%
DATASET_FILENAME = 'llm_hallucination_dataset_v1.csv'
matches = sorted((PROJECT_ROOT / 'Datasets').glob(f'*/{DATASET_FILENAME}'))
if not matches:
    raise FileNotFoundError(f'Could not find {DATASET_FILENAME} under {PROJECT_ROOT / "Datasets"}')
DATASET_PATH = matches[0]
print(DATASET_PATH)
print('File exists:', DATASET_PATH.exists())
# Out:
# D:\APU Study\1st Semester\Applied Machine Learning\AML Assignment\Datasets\LLM Hallucination\llm_hallucination_dataset_v1.csv
# File exists: True

# %%
data = pd.read_csv(DATASET_PATH)
data
# Out:
#                                 record_id created_date      model_name  \
# 0    70b69889-3b46-4b1e-8f83-b95720bddbcd   2024-11-02          GPT-4o
# 1    e93f6574-d3a1-4459-9ccc-8615bc2b627f   2024-09-24   Mistral-Large
# 2    fc732394-9369-4811-8484-e07f69cb6fab   2025-01-29   Mistral-Large
# 3    2e488a3d-bfc4-4d1e-b59b-eeca571c9c27   2024-10-26   Llama-3.1-70B
# 4    eb1c2d1e-9fb6-46f0-9f65-0f36494db9dc   2024-11-07  Gemini-1.5-Pro
# ..                                    ...          ...             ...
# 195  dc1ddb29-e3d9-4651-a570-c7439d420f95   2025-04-03          GPT-4o
# 196  7f2a8697-2deb-4a69-8a08-3802e53886f8   2025-02-26  Gemini-1.5-Pro
# 197  c59849f3-99b3-4646-b8c4-9a7904e24e3b   2024-09-05   Mistral-Large
# 198  a04df3dd-4a1f-4ef8-8d58-04ab3685903d   2024-11-17          GPT-4o
# 199  6067be34-d199-4995-a770-cc3501f96725   2025-01-31          GPT-4o
#
#               model_version     prompt_id  \
# 0         gpt-4o-2024-11-20  PROMPT_00001
# 1        mistral-large-2411  PROMPT_00002
# 2        mistral-large-2411  PROMPT_00003
# 3    llama-3.1-70b-instruct  PROMPT_00004
# 4        gemini-1.5-pro-002  PROMPT_00005
# ..                      ...           ...
# 195       gpt-4o-2024-11-20  PROMPT_00196
# 196      gemini-1.5-pro-002  PROMPT_00197
# 197      mistral-large-2411  PROMPT_00198
# 198       gpt-4o-2024-11-20  PROMPT_00199
# 199       gpt-4o-2024-11-20  PROMPT_00200
#
#                                            prompt_text     prompt_type  \
# 0                          Who invented the telephone?       Multi-Hop
# 1     What is the boiling point of water at sea level?       Multi-Hop
# 2    What is the recommended first-line treatment f...       Ambiguous
# 3                         When was Apple Inc. founded?       Ambiguous
# 4    Is it legal to record a phone call without con...  Direct-Factual
# ..                                                 ...             ...
# 195                When did the Soviet Union collapse?       Ambiguous
# 196                  Summarize what a hedge fund does.       Multi-Hop
# 197                    Can you explain what an API is?       Ambiguous
# 198                 Does the MMR vaccine cause autism?  Direct-Factual
# 199       What is the chemical formula for table salt?    Long-Context
#
#                                          response_text      domain  \
# 0    The telephone was invented by Nikola Tesla in ...     History
# 1    Water boils at 100 degrees Celsius (212 degree...     Science
# 2    The first-line pharmacological treatment for T...    Medicine
# 3    Apple Inc. was founded on April 1, 1976, by St...     Finance
# 4    In California, you can legally record a phone ...         Law
# ..                                                 ...         ...
# 195  The Soviet Union officially dissolved on Decem...     History
# 196  A hedge fund is a pooled investment vehicle th...     Finance
# 197  An API (Application Programming Interface) is ...  Technology
# 198  No. The claim that the MMR vaccine causes auti...    Medicine
# 199  The chemical formula for table salt is NaCl (s...     General
#
#               task_type language  hallucination_label     hallucination_type  \
# 0    Question-Answering  English                    1           Entity-Error
# 1    Question-Answering  English                    0                    NaN
# 2    Question-Answering  Spanish                    1  Factual-Contradiction
# 3    Question-Answering  English                    0                    NaN
# 4     Fact-Verification   French                    1  Factual-Contradiction
# ..                  ...      ...                  ...                    ...
# 195            Dialogue  Spanish                    1         Incompleteness
# 196       Summarization    Hindi                    1  Factual-Contradiction
# 197            Dialogue  English                    0                    NaN
# 198   Fact-Verification  English                    0                    NaN
# 199  Question-Answering  English                    0                    NaN
#
#                                     hallucination_span  \
# 0                                         Nikola Tesla
# 1                                                  NaN
# 2    insulin therapy, which should be initiated at ...
# 3                                                  NaN
# 4                       one party to the call consents
# ..                                                 ...
# 195          officially dissolved on December 25, 1991
# 196  All hedge funds are required to be registered ...
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                    correct_information  \
# 0                                Alexander Graham Bell
# 1                                                  NaN
# 2            Metformin is the standard first-line drug
# 3                                                  NaN
# 4    California requires all-party consent under Pe...
# ..                                                 ...
# 195  Formal dissolution was December 26, 1991 when ...
# 196  Many hedge funds are exempt from SEC registrat...
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                        correction_text severity  domain_risk  \
# 0    The telephone was invented by Alexander Graham...     High   Low-Stakes
# 1                                                  NaN      NaN   Low-Stakes
# 2    Metformin is the recommended first-line pharma...     High  High-Stakes
# 3                                                  NaN      NaN   Low-Stakes
# 4    California is an all-party consent state; all ...     High  High-Stakes
# ..                                                 ...      ...          ...
# 195  Gorbachev resigned on December 25, 1991, but t...      Low   Low-Stakes
# 196  Not all hedge funds are required to register w...   Medium  High-Stakes
# 197                                                NaN      NaN   Low-Stakes
# 198                                                NaN      NaN  High-Stakes
# 199                                                NaN      NaN   Low-Stakes
#
#       annotator_type  annotation_confidence mitigation_strategy  \
# 0       human_expert                   0.73                 RAG
# 1       human_expert                   0.88                 NaN
# 2       human_expert                   0.83    Self-Consistency
# 3        human_crowd                   0.86       CoT-Prompting
# 4       human_expert                   0.95   Structured-Prompt
# ..               ...                    ...                 ...
# 195  llm_judge_gpt4o                   0.81                 NaN
# 196      human_crowd                   0.97    Self-Consistency
# 197  llm_judge_gpt4o                   0.80                 NaN
# 198      human_crowd                   0.95       CoT-Prompting
# 199  llm_judge_gpt4o                   0.82    Self-Consistency
#
#      mitigation_applied verified_source intrinsic_or_extrinsic  notes
# 0                  True          PubMed              Extrinsic    NaN
# 1                 False           ArXiv                    NaN    NaN
# 2                  True      SEC-Filing              Extrinsic    NaN
# 3                  True          PubMed                    NaN    NaN
# 4                  True          Snopes              Extrinsic    NaN
# ..                  ...             ...                    ...    ...
# 195               False       Wikipedia              Intrinsic    NaN
# 196                True    Human-Expert              Extrinsic    NaN
# 197               False          Snopes                    NaN    NaN
# 198                True    Human-Expert                    NaN    NaN
# 199                True      SEC-Filing                    NaN    NaN
#
# [200 rows x 25 columns]

# %%
data.head()
# Out:
#                               record_id created_date      model_name  \
# 0  70b69889-3b46-4b1e-8f83-b95720bddbcd   2024-11-02          GPT-4o
# 1  e93f6574-d3a1-4459-9ccc-8615bc2b627f   2024-09-24   Mistral-Large
# 2  fc732394-9369-4811-8484-e07f69cb6fab   2025-01-29   Mistral-Large
# 3  2e488a3d-bfc4-4d1e-b59b-eeca571c9c27   2024-10-26   Llama-3.1-70B
# 4  eb1c2d1e-9fb6-46f0-9f65-0f36494db9dc   2024-11-07  Gemini-1.5-Pro
#
#             model_version     prompt_id  \
# 0       gpt-4o-2024-11-20  PROMPT_00001
# 1      mistral-large-2411  PROMPT_00002
# 2      mistral-large-2411  PROMPT_00003
# 3  llama-3.1-70b-instruct  PROMPT_00004
# 4      gemini-1.5-pro-002  PROMPT_00005
#
#                                          prompt_text     prompt_type  \
# 0                        Who invented the telephone?       Multi-Hop
# 1   What is the boiling point of water at sea level?       Multi-Hop
# 2  What is the recommended first-line treatment f...       Ambiguous
# 3                       When was Apple Inc. founded?       Ambiguous
# 4  Is it legal to record a phone call without con...  Direct-Factual
#
#                                        response_text    domain  \
# 0  The telephone was invented by Nikola Tesla in ...   History
# 1  Water boils at 100 degrees Celsius (212 degree...   Science
# 2  The first-line pharmacological treatment for T...  Medicine
# 3  Apple Inc. was founded on April 1, 1976, by St...   Finance
# 4  In California, you can legally record a phone ...       Law
#
#             task_type language  hallucination_label     hallucination_type  \
# 0  Question-Answering  English                    1           Entity-Error
# 1  Question-Answering  English                    0                    NaN
# 2  Question-Answering  Spanish                    1  Factual-Contradiction
# 3  Question-Answering  English                    0                    NaN
# 4   Fact-Verification   French                    1  Factual-Contradiction
#
#                                   hallucination_span  \
# 0                                       Nikola Tesla
# 1                                                NaN
# 2  insulin therapy, which should be initiated at ...
# 3                                                NaN
# 4                     one party to the call consents
#
#                                  correct_information  \
# 0                              Alexander Graham Bell
# 1                                                NaN
# 2          Metformin is the standard first-line drug
# 3                                                NaN
# 4  California requires all-party consent under Pe...
#
#                                      correction_text severity  domain_risk  \
# 0  The telephone was invented by Alexander Graham...     High   Low-Stakes
# 1                                                NaN      NaN   Low-Stakes
# 2  Metformin is the recommended first-line pharma...     High  High-Stakes
# 3                                                NaN      NaN   Low-Stakes
# 4  California is an all-party consent state; all ...     High  High-Stakes
#
#   annotator_type  annotation_confidence mitigation_strategy  \
# 0   human_expert                   0.73                 RAG
# 1   human_expert                   0.88                 NaN
# 2   human_expert                   0.83    Self-Consistency
# 3    human_crowd                   0.86       CoT-Prompting
# 4   human_expert                   0.95   Structured-Prompt
#
#    mitigation_applied verified_source intrinsic_or_extrinsic  notes
# 0                True          PubMed              Extrinsic    NaN
# 1               False           ArXiv                    NaN    NaN
# 2                True      SEC-Filing              Extrinsic    NaN
# 3                True          PubMed                    NaN    NaN
# 4                True          Snopes              Extrinsic    NaN

# %%
data.tail()
# Out:
#                                 record_id created_date      model_name  \
# 195  dc1ddb29-e3d9-4651-a570-c7439d420f95   2025-04-03          GPT-4o
# 196  7f2a8697-2deb-4a69-8a08-3802e53886f8   2025-02-26  Gemini-1.5-Pro
# 197  c59849f3-99b3-4646-b8c4-9a7904e24e3b   2024-09-05   Mistral-Large
# 198  a04df3dd-4a1f-4ef8-8d58-04ab3685903d   2024-11-17          GPT-4o
# 199  6067be34-d199-4995-a770-cc3501f96725   2025-01-31          GPT-4o
#
#           model_version     prompt_id  \
# 195   gpt-4o-2024-11-20  PROMPT_00196
# 196  gemini-1.5-pro-002  PROMPT_00197
# 197  mistral-large-2411  PROMPT_00198
# 198   gpt-4o-2024-11-20  PROMPT_00199
# 199   gpt-4o-2024-11-20  PROMPT_00200
#
#                                       prompt_text     prompt_type  \
# 195           When did the Soviet Union collapse?       Ambiguous
# 196             Summarize what a hedge fund does.       Multi-Hop
# 197               Can you explain what an API is?       Ambiguous
# 198            Does the MMR vaccine cause autism?  Direct-Factual
# 199  What is the chemical formula for table salt?    Long-Context
#
#                                          response_text      domain  \
# 195  The Soviet Union officially dissolved on Decem...     History
# 196  A hedge fund is a pooled investment vehicle th...     Finance
# 197  An API (Application Programming Interface) is ...  Technology
# 198  No. The claim that the MMR vaccine causes auti...    Medicine
# 199  The chemical formula for table salt is NaCl (s...     General
#
#               task_type language  hallucination_label     hallucination_type  \
# 195            Dialogue  Spanish                    1         Incompleteness
# 196       Summarization    Hindi                    1  Factual-Contradiction
# 197            Dialogue  English                    0                    NaN
# 198   Fact-Verification  English                    0                    NaN
# 199  Question-Answering  English                    0                    NaN
#
#                                     hallucination_span  \
# 195          officially dissolved on December 25, 1991
# 196  All hedge funds are required to be registered ...
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                    correct_information  \
# 195  Formal dissolution was December 26, 1991 when ...
# 196  Many hedge funds are exempt from SEC registrat...
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                        correction_text severity  domain_risk  \
# 195  Gorbachev resigned on December 25, 1991, but t...      Low   Low-Stakes
# 196  Not all hedge funds are required to register w...   Medium  High-Stakes
# 197                                                NaN      NaN   Low-Stakes
# 198                                                NaN      NaN  High-Stakes
# 199                                                NaN      NaN   Low-Stakes
#
#       annotator_type  annotation_confidence mitigation_strategy  \
# 195  llm_judge_gpt4o                   0.81                 NaN
# 196      human_crowd                   0.97    Self-Consistency
# 197  llm_judge_gpt4o                   0.80                 NaN
# 198      human_crowd                   0.95       CoT-Prompting
# 199  llm_judge_gpt4o                   0.82    Self-Consistency
#
#      mitigation_applied verified_source intrinsic_or_extrinsic  notes
# 195               False       Wikipedia              Intrinsic    NaN
# 196                True    Human-Expert              Extrinsic    NaN
# 197               False          Snopes                    NaN    NaN
# 198                True    Human-Expert                    NaN    NaN
# 199                True      SEC-Filing                    NaN    NaN

# %%
data.shape
# Out:
# (200, 25)

# %%
list(data.columns)
# Out:
# ['record_id',
#  'created_date',
#  'model_name',
#  'model_version',
#  'prompt_id',
#  'prompt_text',
#  'prompt_type',
#  'response_text',
#  'domain',
#  'task_type',
#  'language',
#  'hallucination_label',
#  'hallucination_type',
#  'hallucination_span',
#  'correct_information',
#  'correction_text',
#  'severity',
#  'domain_risk',
#  'annotator_type',
#  'annotation_confidence',
#  'mitigation_strategy',
#  'mitigation_applied',
#  'verified_source',
#  'intrinsic_or_extrinsic',
#  'notes']

# %%
data.dtypes
# Out:
# record_id                     str
# created_date                  str
# model_name                    str
# model_version                 str
# prompt_id                     str
#                            ...
# mitigation_strategy           str
# mitigation_applied           bool
# verified_source               str
# intrinsic_or_extrinsic        str
# notes                     float64
# Length: 25, dtype: object

# %% [markdown]
# ## What was learned from Lab 1
#
# The dataset was loaded from `Datasets/LLM Hallucination/llm_hallucination_dataset_v1.csv` using pandas. At this stage we only confirm that the file can be read and that the dataframe structure is visible. Data cleaning, preprocessing, and modelling are intentionally left for later labs.
