# %% [markdown]
# ### **Installing Python and IDE**

# %% [markdown]
# Refer to the **Python Installation Guide** document.
# 1. Install Python (Reccommended Python version is 3.11.9, which is the most stable and bug free version)
# 2. Select the preferred IDE and install. VSCode is reccommended.
# 3. Install the following libraries one by one:
#     1. Pandas (%pip install pandas)
#     2. Matplotlib (%pip install matplotlib)
#     3. Seaborn (%pip install seaborn)
#     4. Scikit-Learn (%pip install scikit-learn)
#
# Please go through the **Cheat Sheets** provided after the lab class. These cheat sheets give guidelines on the prominent functions that every library offers.
#
# **TF-KERAS Installation Guide** document gives the guideline to install Keras-Tensorflow library. We will install this library when starting the topic ANN.

# %%
# Example
# %pip install pandas

# %% [markdown]
# **LOAD A DATASET**
#
# Load the data using the Pandas library. Pandas library can read/write the following data file formats.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Load using a CSV file**

# %%
# %pip install pandas

# %%
import pandas as pd
data = pd.read_csv('C:/APU/CT046-3-M-AML/CT046 - LABS/Python LAB MATERIALS/Lab 1 - Installing IDE_Data Loading/telecom_churn.csv')
data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# **Load using an excel file**

# %%
# %pip install openpyxl

# %%
import pandas as pd
data_xls = pd.read_excel('C:/APU/CT046-3-M-AML/CT046 - LABS/Python LAB MATERIALS/Lab 1 - Installing IDE_Data Loading/AmazingMartEU2.xlsx', sheet_name = 'OrderBreakdown')
data_xls
# Out:
#              Order ID                           Product Name  Discount  Sales  \
# 0     BN-2011-7407039            Enermax Note Cards, Premium       0.5     45
# 1     AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0    854
# 2     AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0    140
# 3     BN-2011-2819714             Boston Markers, Easy-Erase       0.5     27
# 4     BN-2011-2819714            Eldon Folders, Single Width       0.5     17
# ...               ...                                    ...       ...    ...
# 8042   AZ-2014-766953   Ikea Stackable Bookrack, Traditional       0.0    245
# 8043  BN-2014-4140795      BIC Pencil Sharpener, Fluorescent       0.5     30
# 8044  BN-2014-4140795          Avery Binder Covers, Recycled       0.5     23
# 8045  BN-2014-4140795                    StarTech Phone, Red       0.5    108
# 8046   AZ-2014-766953              Motorola Audio Dock, VoIP       0.0    867
#
# ...

# %% [markdown]
# **Load using a URL**

# %%
import pandas as pd
data_url = pd.read_csv('https://raw.githubusercontent.com/sharmaroshan/Churn-Modelling-Dataset/master/Churn_Modelling.csv')
data_url

# %% [markdown]
# **VIEW DATASET**

# %%
# can use this to display all the columns of the dataset
pd.set_option('display.max_columns', None)

# %%
# can use this to display all the rows of the dataset
pd.set_option('display.max_rows', None)
